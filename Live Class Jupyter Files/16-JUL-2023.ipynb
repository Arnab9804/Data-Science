# %% [markdown]
# # Working with PANDAS

# %% [markdown]
# Set Index

# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.DataFrame({'Day':[1,2,3,4],'Visitors':[200,100,300,230],'Bounce_Rate':[20,45,60,10]})

print(df)
# Out:
#    Day  Visitors  Bounce_Rate
# 0    1       200           20
# 1    2       100           45
# 2    3       300           60
# 3    4       230           10

# %%
df
# Out:
#    Day  Visitors  Bounce_Rate
# 0    1       200           20
# 1    2       100           45
# 2    3       300           60
# 3    4       230           10

# %%
df.set_index('Day',inplace=True)

# %%
df
# Out:
#      Visitors  Bounce_Rate
# Day
# 1         200           20
# 2         100           45
# 3         300           60
# 4         230           10

# %%
dict1={'id':[1,2,3,4],'Name':['Arnab','Amit','Sourav','Prantik'],'Age':[30,34,33,31]}

# %%
dict1
# Out:
# {'id': [1, 2, 3, 4],
#  'Name': ['Arnab', 'Amit', 'Sourav', 'Prantik'],
#  'Age': [30, 34, 33, 31]}

# %%
df1=pd.DataFrame(dict1)

df1
# Out:
#    id     Name  Age
# 0   1    Arnab   30
# 1   2     Amit   34
# 2   3   Sourav   33
# 3   4  Prantik   31

# %%
df1
# Out:
#    id     Name  Age
# 0   1    Arnab   30
# 1   2     Amit   34
# 2   3   Sourav   33
# 3   4  Prantik   31

# %%
df1.set_index('id',inplace=True)

# %%
df1
# Out:
#        Name  Age
# id
# 1     Arnab   30
# 2      Amit   34
# 3    Sourav   33
# 4   Prantik   31

# %%
df1.rename(columns={'Name':'Empname','Age':'EmpAge'})
# Out:
#     Empname  EmpAge
# id
# 1     Arnab      30
# 2      Amit      34
# 3    Sourav      33
# 4   Prantik      31

# %%
data={'Day':[1,2,3,4,5,6],'Visitors':[200,100,300,230,240,360],'Bounce_Rate':[20,45,60,10,25,20]}

# %%
data
# Out:
# {'Day': [1, 2, 3, 4, 5, 6],
#  'Visitors': [200, 100, 300, 230, 240, 360],
#  'Bounce_Rate': [20, 45, 60, 10, 25, 20]}

# %%
df3=pd.DataFrame(data)

df3
# Out:
#    Day  Visitors  Bounce_Rate
# 0    1       200           20
# 1    2       100           45
# 2    3       300           60
# 3    4       230           10
# 4    5       240           25
# 5    6       360           20

# %%
df3.head(3)
# Out:
#    Day  Visitors  Bounce_Rate
# 0    1       200           20
# 1    2       100           45
# 2    3       300           60

# %%
df3.tail(3)
# Out:
#    Day  Visitors  Bounce_Rate
# 3    4       230           10
# 4    5       240           25
# 5    6       360           20

# %%
df3.sample()
# Out:
#    Day  Visitors  Bounce_Rate
# 1    2       100           45

# %%
df3.sample(2)
# Out:
#    Day  Visitors  Bounce_Rate
# 4    5       240           25
# 3    4       230           10

# %% [markdown]
# # PANDAS INPUT/OUTPUT TOOL

# %%
df=pd.read_csv('emp_test.csv') #how do we input csv file

# %%
df
# Out:
#    Eno    Ename  Esalary  EAge
# 0    1    Arnab    40000    30
# 1    2  prantik    30000    31
# 2    3   sourav    25000    33

# %%
df=pd.read_csv('emp_test.csv',index_col='Empno',header=0,names=['Empno','EmpName','EmpSalary','EmpAge'])

# %%
df
# Out:
#        EmpName  EmpSalary  EmpAge
# Empno
# 1        Arnab      40000      30
# 2      prantik      30000      31
# 3       sourav      25000      33

# %%
df1=pd.read_csv('TEST.csv')

# %%
df1
# Out:
#     Sr.No First Name  Last Name  Gender        Country  Age        Date    Id
# 0       1      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 1       2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2       3     Philip       Gent    Male         France   36  21/05/2015  2587
# 3       4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 4       5    Nereida    Magwood  Female  United States   58  16/08/2016  2468
# 5       6     Gaston      Brumm    Male  United States   24  21/05/2015  2554
# 6       7       Etta       Hurn  Female  Great Britain   56  15/10/2017  3598
# 7       8    Earlean     Melgar  Female  United States   27  16/08/2016  2456
# 8       9   Vincenza    Weiland  Female  United States   40  21/05/2015  6548
# 9      10     Fallon    Winward  Female  Great Britain   28  16/08/2016  5486
# 10     11    Arcelia     Bouska  Female  Great Britain   39  21/05/2015  1258
# ...

# %%
df1=pd.read_csv('TEST.csv',index_col='Sr.No' )

# %%
df1
# Out:
#       First Name  Last Name  Gender        Country  Age        Date    Id
# Sr.No
# 1          Dulce      Abril  Female  United States   32  15/10/2017  1562
# 2           Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 3         Philip       Gent    Male         France   36  21/05/2015  2587
# 4       Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 5        Nereida    Magwood  Female  United States   58  16/08/2016  2468
# 6         Gaston      Brumm    Male  United States   24  21/05/2015  2554
# 7           Etta       Hurn  Female  Great Britain   56  15/10/2017  3598
# 8        Earlean     Melgar  Female  United States   27  16/08/2016  2456
# 9       Vincenza    Weiland  Female  United States   40  21/05/2015  6548
# 10        Fallon    Winward  Female  Great Britain   28  16/08/2016  5486
# 11       Arcelia     Bouska  Female  Great Britain   39  21/05/2015  1258
# 12      Franklyn     Unknow    Male         France   38  15/10/2017  2579
# ...

# %%
df1['First Name'][0]
# Out:
# 'Dulce'

# %%
type(df1['First Name'][0])
# Out:
# str

# %%
df1.to_csv('TEST_store.csv')

# %%
df1=pd.read_csv('TEST_store.csv')

# %%
df1['Age'].plot.box()
# Out:
# <Axes: >

# %%
df1['Age'].plot.bar()
# Out:
# <Axes: >

# %%
df1['Age'].min()
# Out:
# 21

# %%
df1['Age'].max()
# Out:
# 58
