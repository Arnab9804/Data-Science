# %% [markdown]
# # Gradient Descent Algorithm

# %%
import numpy as np
import pandas as pd

import sklearn
from sklearn import linear_model
from sklearn.linear_model import SGDRegressor
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.pipeline import Pipeline

from sklearn.datasets import load_boston

# %%
x=load_boston()
data=pd.DataFrame(x.data,columns=x.feature_names)
y=x.target

# %%
df=data
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
#Creating Model
pipe=[]
pipe.append(('SC',StandardScaler()))
pipe.append(('PCA', PCA(n_components=8)))
pipe.append(('SGD',SGDRegressor()))

model=Pipeline(pipe)
CV_score=cross_val_score(model,data,y,cv=5)
score= '%s: %f (%f)'% ('SGDRegressor',CV_score.mean(),CV_score.std())
print (score)
# Out:
# SGDRegressor: 0.479177 (0.302506)

# %%
pipe=[]
pipe.append(('SC',StandardScaler()))
pipe.append(('PCA', PCA(n_components=8)))
pipe.append(('SGD',SGDRegressor()))

model=Pipeline(pipe)
CV_score=cross_val_score(model,data,y,cv=5)
print ('SGDRegressor:',CV_score.mean(),CV_score.std())
# Out:
# SGDRegressor: 0.48400608412026963 0.2932887428065711

# %% [markdown]
# # Gridsearch CV

# %%
from sklearn import datasets
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

dataset= datasets.load_diabetes()
alphavalue={'alpha':[1,0.01,0.001,0.0001,0]}

rd= Ridge()
grid= GridSearchCV(rd,alphavalue)

grid.fit (dataset.data,dataset.target)
print (grid)

print (grid.best_score_)
print (grid.best_params_)
# Out:
# GridSearchCV(estimator=Ridge(),
#              param_grid={'alpha': [1, 0.01, 0.001, 0.0001, 0]})
# 0.4823214545225415
# {'alpha': 0.0001}
